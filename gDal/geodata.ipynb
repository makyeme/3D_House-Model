# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rioxarray as rxr
import earthpy as et
import gdal
import rasterio

# %%
path1 = 'C:/Users/makye/Downloads/geotiff/DSM/ExtractedDSM/DHMVIIDSMRAS1m_k01/GeoTIFF/DHMVIIDSMRAS1m_k01.tif'
path2 = 'C:/Users/makye/Downloads/geotiff/DTM/DHMVIIDTMRAS1m_k01/GeoTIFF/DHMVIIDTMRAS1m_k01.tif'
fnout = 'C:/Users/makye/Downloads/geotiff'

# %%
# import first dsm image
dsm = gdal.Open(path1)
gt = dsm.GetGeoTransform() #Transforming tiff image
proj = dsm.GetProjection() #projecting tiff image
band = dsm.GetRasterBand(1) #accessing first band(layer) of file
array1 = band.ReadAsArray() #Reading first band of file

#Plot image
plt.figure()
plt.imshow(array1)

# gdal.UseExceptions()

# %%
# import first dtm image
dtm = gdal.Open(path2)
gt = dtm.GetGeoTransform()
proj = dtm.GetProjection()

band = dtm.GetRasterBand(1)
array2 = band.ReadAsArray()

plt.figure()
plt.imshow(array2)
plt.close()
